# %%
#numbers

# %%
#type (): returns the type of the variable
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
x = 1    # int
y = 44.8  # float
z = 3+5j   # complex
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
#Type Conversion
x = 1    # int
print("Before type conversion:",type(x))
#convert from int to float:
a = float(x)
print("After type conversion:",type(a))
# Out:
# Before type conversion: <class 'int'>
# After type conversion: <class 'float'>

# %%
#random number 
''' Python does not have a random() function to make a random number, 
but Python has a built-in module called random that can be used to make random numbers  '''
import random

print(random.randrange(1, 10))
# Out:
# 9

# %%
#strings slicing
''' Get the characters from position 2 to position 5 (not included) '''
b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %%
b = "Hello, World!"
print(b[:])
# Out:
# Hello, World!

# %%
#remove whitespace
''' The strip() method removes any whitespace from the beginning or the end '''
a = " Hello, World! "
print(a.strip())
# Out:
# Hello, World!

# %%
''' The split() method splits the string into substrings if it finds instances of the separator '''
a = "Hello,World!"
print(a.split(","))
# Out:
# ['Hello', 'World!']

# %%
print(a.split(" "))# here seperator is space
# Out:
# ['Hello,World!']

# %%
print(a.split("")) #it will give value error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(a.split("")) #it will give value error
#
# ValueError: empty separator

# %%
#string concatenation
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
''' To specify a string as an f-string, simply put an f in front of the string literal, 
and add curly brackets {} as placeholders for variables and other operations.
'''
price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %%
''' Escape Character
To insert characters that are illegal in a string, use an escape character. 
example: 
txt = "We are the so-called "Vikings" from the north. "  #this will give error
 '''
txt = "We are the so-called \"Vikings\" from the north."
print(txt)
# Out:
# We are the so-called "Vikings" from the north.

# %%
#booleans
'''Booleans represent one of two values: True or False.'''
print(14 > 9)
print(111 == 9)
print(10 < 9)
# Out:
# True
# False
# False

# %%
x = "Hello"
y = 15

print(bool(x))
print(bool(y))
# Out:
# True
# True

# %%
'''
:= operator, known as the "walrus operator". 
It assigns values to variables as part of a larger expression
'''
numbers = [1, 2, 3, 4, 5]
count = len(numbers)
if count > 3:
    print(f"List has {count} elements")

if (count := len(numbers)) > 3:
    print(f"List has {count} elements")
# Out:
# List has 5 elements
# List has 5 elements

# %%
''' 
Identity operators are used to compare the objects, not if they are equal, 
but if they are actually the same object, with the same memory location

is 	:Returns True if both variables are the same object	x is y	
is not	:Returns True if both variables are not the same object	x is not y

'''
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x

print(x is z)# it compares memory locations
print(x is y)
print(x == y)# it compares values
print (x is not y)
print (x is not z)# it compares memory locations
# Out:
# True
# False
# True
# True
# False

# %%
'''
Membership operators are used to test if a sequence is presented in an object
in 	Returns True if a sequence with the specified value is present in the object	x in y	
not in	Returns True if a sequence with the specified value is not present in the object	x not in y
'''
fruits = ["apple", "banana", "cherry"]

print("banana" in fruits)
print ("cake"in fruits)
print("pineapple" not in fruits)
print ("cake"not in fruits)
# Out:
# True
# False
# True
# True

# %%
''' Bitwise Operators 
& 	AND	Sets each bit to 1 if both bits are 1	x & y	
|	OR	Sets each bit to 1 if one of two bits is 1	x | y	
^	XOR	Sets each bit to 1 if only one of two bits is 1	x ^ y	
~	NOT	Inverts all the bits	~x	
<<	Zero fill left shift	Shift left by pushing zeros in from the right and let the leftmost bits fall off	x << 2	
>>	Signed right shift	Shift right by pushing copies of the leftmost bit in from the left, and let the rightmost bits fall off	x >>2

 '''
print(6 & 3)
print (True & False)
print(6 | 3)
print (True | False)
print(6 ^ 3)
print (True ^ False)
# Out:
# 2
# False
# 7
# True
# 5
# True
