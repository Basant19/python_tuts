# %%
#reursion 
def check(num):
    if num<0:
        return
    print (num)
    check(num-1)
check(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
def check(num):
    if num<0:
        return
    check(num-1)
    print (num)
    
check(5)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
def printnum(i,n):
    if i>n:
        return
    print (i)
    printnum(i+1,n)
printnum(1,5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def fact(num):
    if num==0:
        return 1
    return num*fact(num-1)

print(fact(5))
# Out:
# 120
